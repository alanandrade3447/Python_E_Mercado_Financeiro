# %%
import matplotlib.pyplot as plt
import numpy as np
import statistics as stats
import scipy.stats as sp
from scipy.stats import norm
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\alana\OneDrive\Documentos\GitHub\Python_E_Mercado_Financeiro\BTC-USD.csv")

# %%
retorno = (df['Close'].iloc[1:] - df['Close'].iloc[:-1].values) / df['Close'].iloc[:-1].values

# %% [markdown]
# # Gráfico BitCoin diário

# %%
plt.subplot(221)
plt.plot(df.index, df['Close'],color='black')
plt.xlabel('Dias')
plt.title('BitCoin diário (2018-Fev/2023-Mai)')
# Out:
# Text(0.5, 1.0, 'BitCoin diário (2018-Fev/2023-Mai)')

# %% [markdown]
# # Gráfico retorno

# %%
df_subset = df.iloc[1:, :]

# %%
plt.subplot(222)
plt.plot(df_subset.index,retorno,color='black')
plt.xlabel('Dias')
plt.title('BitCoin - retorno diário')
# Out:
# Text(0.5, 1.0, 'BitCoin - retorno diário')

# %% [markdown]
# # Gráfico histograma e dist.normal

# %%
plt.subplot(223)
plt.hist(retorno,bins=20,color='gray',density=True)
plt.xlabel('Classes')
plt.ylabel('Frequência')
plt.title('Histograma dos retornos - BitCoin')
xmin, xmax = plt.xlim()
media=stats.mean(retorno)
desvio=stats.pstdev(retorno)
eixo_x = np.linspace(xmin,xmax,100)
eixo_y = norm.pdf(eixo_x,media,desvio)
plt.plot(eixo_x,eixo_y,color='black')

# %% [markdown]
# # Gráfico QQ-Plot  - (Quantile Quantile Plot)

# %%
plt.subplot(224)
sp.probplot(retorno,dist="norm", plot=plt)
plt.title('QQ-Plot BitCoin')
# Out:
# Text(0.5, 1.0, 'QQ-Plot BitCoin')
