# %%
import matplotlib.pyplot as plt
import statistics as stats
import numpy as np
import scipy.stats as sp
from scipy.stats import norm
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\alana\OneDrive\Documentos\Python_Mercado_Financeiro\^BVSP.csv")

# %%
print(df)
# Out:
#             Date      Open      High       Low     Close  Adj Close    Volume
# 0     2018-01-02   76403.0   77909.0   76403.0   77891.0    77891.0   2880300
# 1     2018-01-03   77889.0   78414.0   77602.0   77995.0    77995.0   3142200
# 2     2018-01-04   77998.0   79135.0   77998.0   78647.0    78647.0   3486100
# 3     2018-01-05   78644.0   79071.0   78218.0   79071.0    79071.0   2747100
# 4     2018-01-08   79070.0   79395.0   78631.0   79379.0    79379.0   2550800
# ...          ...       ...       ...       ...       ...        ...       ...
# 1320  2023-05-03  101927.0  102331.0  101433.0  101797.0   101797.0  11688200
# 1321  2023-05-04  101798.0  103321.0  101063.0  102174.0   102174.0  14837300
# 1322  2023-05-05  102175.0  105306.0  102175.0  105148.0   105148.0  16699500
# 1323  2023-05-08  105161.0  106716.0  105161.0  106042.0   106042.0  13259200
# 1324  2023-05-09  106028.0  107731.0  105549.0  107114.0   107114.0  13526600
#
# [1325 rows x 7 columns]

# %%
# Cálculo do retorno

# %%
retorno = (df['Close'].iloc[1:] - df['Close'].iloc[:-1].values) / df['Close'].iloc[:-1].values

# %%
retorno.head()
# Out:
# 1    0.001335
# 2    0.008360
# 3    0.005391
# 4    0.003895
# 5   -0.006488
# Name: Close, dtype: float64

# %%
# Gráfico Ibovespa diário

# %%
plt.subplot(221)
plt.plot(df.index, df['Close'],color='black')
plt.xlabel('Dias')
plt.title('Ibovespa diário (2018-Fev/2023-Mai)')
# Out:
# Text(0.5, 1.0, 'Ibovespa diário (2018-Fev/2023-Mai)')

# %%
# Gráfico retorno

# %%
df.to_csv('C:\\Users\\alana\\OneDrive\\Documentos\\Python_Mercado_Financeiro\\arquivo.csv')

# %%
df_subset = df.iloc[1:, :]

# %%
plt.subplot(222)
plt.plot(df_subset.index,retorno,color='black')
plt.xlabel('Dias')
plt.title('Ibovespa - retorno diário')
# Out:
# Text(0.5, 1.0, 'Ibovespa - retorno diário')

# %%
# Gráfico histograma e dist.normal

# %%
plt.subplot(223)
plt.hist(retorno,bins=20,color='gray',density=True)
plt.xlabel('Classes')
plt.ylabel('Frequência')
plt.title('Histograma dos retornos - Ibovespa')
xmin, xmax = plt.xlim()
media=stats.mean(retorno)
desvio=stats.pstdev(retorno)
eixo_x = np.linspace(xmin,xmax,100)
eixo_y = norm.pdf(eixo_x,media,desvio)
plt.plot(eixo_x,eixo_y,color='black')

# %%
# Gráfico QQ-Plot  - (Quantile Quantile Plot)

# %%
plt.subplot(224)
sp.probplot(retorno,dist="norm", plot=plt)
plt.title('QQ-Plot Ibovespa')
# Out:
# Text(0.5, 1.0, 'QQ-Plot Ibovespa')
